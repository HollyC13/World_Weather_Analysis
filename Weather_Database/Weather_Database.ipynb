# %%
# Import the dependencies
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy mocule to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval                        ")
print("------------------------------------------------")

# Create counters
record_counter = 1
set_count = 1

# Loop through all the cities in our list
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
#
#  Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
# Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------------
# Processing Record 1 of Set 16 | kuminskiy
# Processing Record 2 of Set 16 | kapaa
# Processing Record 3 of Set 16 | zaliztsi
# Processing Record 4 of Set 16 | atuona
# Processing Record 5 of Set 16 | puerto ayora
# Processing Record 6 of Set 16 | vaini
# Processing Record 7 of Set 16 | rikitea
# Processing Record 8 of Set 16 | hermanus
# Processing Record 9 of Set 16 | bogovarovo
# Processing Record 10 of Set 16 | mar del plata
# Processing Record 11 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 16 | albany
# Processing Record 13 of Set 16 | havre-saint-pierre
# Processing Record 14 of Set 16 | mafinga
# Processing Record 15 of Set 16 | chumphon
# Processing Record 16 of Set 16 | yar-sale
# Processing Record 17 of Set 16 | mataura
# Processing Record 18 of Set 16 | rawson
# Processing Record 19 of Set 16 | qeshm
# Processing Record 20 of Set 16 | katsuura
# Processing Record 21 of Set 16 | port elizabeth
# Processing Record 22 of Set 16 | cap-aux-meules
# Processing Record 23 of Set 16 | souillac
# Processing Record 24 of Set 16 | ushuaia
# Processing Record 25 of Set 16 | jamestown
# Processing Record 26 of Set 16 | constitucion
# Processing Record 27 of Set 16 | lenger
# Processing Record 28 of Set 16 | sinnamary
# Processing Record 29 of Set 16 | vila franca do campo
# Processing Record 30 of Set 16 | saint-pierre
# Processing Record 31 of Set 16 | borovoy
# Processing Record 32 of Set 16 | warmbad
# Processing Record 33 of Set 16 | avarua
# Processing Record 34 of Set 16 | hithadhoo
# Processing Record 35 of Set 16 | bethel
# Processing Record 36 of Set 16 | inuvik
# Processing Record 37 of Set 16 | homer
# Processing Record 38 of Set 16 | zhitikara
# City not found. Skipping...
# Processing Record 39 of Set 16 | guerrero negro
# Processing Record 40 of Set 16 | alofi
# Processing Record 41 of Set 16 | ponta do sol
# Processing Record 42 of Set 16 | chuy
# Processing Record 43 of Set 16 | hvide sande
# Processing Record 44 of Set 16 | lebu
# Processing Record 45 of Set 16 | podor
# Processing Record 46 of Set 16 | mount gambier
# Processing Record 47 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 16 | busselton
# Processing Record 49 of Set 16 | qaanaaq
# Processing Record 50 of Set 16 | odweyne
# Processing Record 1 of Set 17 | pangnirtung
# Processing Record 2 of Set 17 | yellowknife
# Processing Record 3 of Set 17 | upernavik
# Processing Record 4 of Set 17 | smithers
# Processing Record 5 of Set 17 | naze
# Processing Record 6 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 17 | hobyo
# Processing Record 8 of Set 17 | klaksvik
# Processing Record 9 of Set 17 | morondava
# Processing Record 10 of Set 17 | kavieng
# Processing Record 11 of Set 17 | soyo
# Processing Record 12 of Set 17 | provideniya
# Processing Record 13 of Set 17 | buarcos
# Processing Record 14 of Set 17 | cherskiy
# Processing Record 15 of Set 17 | bahir dar
# Processing Record 16 of Set 17 | bluff
# Processing Record 17 of Set 17 | punta arenas
# Processing Record 18 of Set 17 | bubaque
# Processing Record 19 of Set 17 | coquimbo
# Processing Record 20 of Set 17 | longyearbyen
# Processing Record 21 of Set 17 | banda aceh
# Processing Record 22 of Set 17 | la macarena
# Processing Record 23 of Set 17 | eureka
# Processing Record 24 of Set 17 | itoman
# Processing Record 25 of Set 17 | chokurdakh
# Processing Record 26 of Set 17 | thompson
# Processing Record 27 of Set 17 | buta
# Processing Record 28 of Set 17 | qandala
# Processing Record 29 of Set 17 | puerto del rosario
# Processing Record 30 of Set 17 | kaitangata
# Processing Record 31 of Set 17 | dikson
# Processing Record 32 of Set 17 | bismarck
# Processing Record 33 of Set 17 | necochea
# Processing Record 34 of Set 17 | butaritari
# Processing Record 35 of Set 17 | praia
# Processing Record 36 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 17 | mareeba
# Processing Record 38 of Set 17 | codrington
# Processing Record 39 of Set 17 | sao filipe
# Processing Record 40 of Set 17 | new norfolk
# Processing Record 41 of Set 17 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 17 | yaan
# Processing Record 43 of Set 17 | kahului
# Processing Record 44 of Set 17 | carnarvon
# Processing Record 45 of Set 17 | port lincoln
# Processing Record 46 of Set 17 | iqaluit
# Processing Record 47 of Set 17 | roebourne
# Processing Record 48 of Set 17 | cheremshanka
# Processing Record 49 of Set 17 | avera
# Processing Record 50 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 18 | dubbo
# Processing Record 2 of Set 18 | bredasdorp
# Processing Record 3 of Set 18 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 18 | mayo
# Processing Record 5 of Set 18 | kloulklubed
# Processing Record 6 of Set 18 | usinsk
# Processing Record 7 of Set 18 | matongo
# Processing Record 8 of Set 18 | kurmanayevka
# Processing Record 9 of Set 18 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 18 | bengkulu
# Processing Record 11 of Set 18 | saint-philippe
# Processing Record 12 of Set 18 | lavrentiya
# Processing Record 13 of Set 18 | port shepstone
# Processing Record 14 of Set 18 | olafsvik
# Processing Record 15 of Set 18 | salinopolis
# Processing Record 16 of Set 18 | nome
# Processing Record 17 of Set 18 | hobart
# Processing Record 18 of Set 18 | ribeira grande
# Processing Record 19 of Set 18 | port alfred
# Processing Record 20 of Set 18 | dingle
# Processing Record 21 of Set 18 | nanortalik
# Processing Record 22 of Set 18 | nishihara
# Processing Record 23 of Set 18 | beringovskiy
# Processing Record 24 of Set 18 | bizhbulyak
# Processing Record 25 of Set 18 | kainantu
# Processing Record 26 of Set 18 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 18 | fuerte olimpo
# Processing Record 28 of Set 18 | bathurst
# Processing Record 29 of Set 18 | brainerd
# Processing Record 30 of Set 18 | nantucket
# Processing Record 31 of Set 18 | sitka
# Processing Record 32 of Set 18 | okhotsk
# Processing Record 33 of Set 18 | aykhal
# Processing Record 34 of Set 18 | cape town
# Processing Record 35 of Set 18 | deputatskiy
# Processing Record 36 of Set 18 | diofior
# Processing Record 37 of Set 18 | adrar
# Processing Record 38 of Set 18 | ilulissat
# Processing Record 39 of Set 18 | buraydah
# Processing Record 40 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 18 | lappeenranta
# Processing Record 42 of Set 18 | lompoc
# Processing Record 43 of Set 18 | georgetown
# Processing Record 44 of Set 18 | vestmanna
# Processing Record 45 of Set 18 | port blair
# Processing Record 46 of Set 18 | quelimane
# Processing Record 47 of Set 18 | tuktoyaktuk
# Processing Record 48 of Set 18 | la ronge
# Processing Record 49 of Set 18 | barra do corda
# Processing Record 50 of Set 18 | ifanadiana
# Processing Record 1 of Set 19 | yoichi
# Processing Record 2 of Set 19 | barrow
# Processing Record 3 of Set 19 | severnoye
# Processing Record 4 of Set 19 | hami
# Processing Record 5 of Set 19 | saldanha
# Processing Record 6 of Set 19 | port hardy
# Processing Record 7 of Set 19 | vardo
# Processing Record 8 of Set 19 | lagunas
# Processing Record 9 of Set 19 | san lawrenz
# Processing Record 10 of Set 19 | srednekolymsk
# Processing Record 11 of Set 19 | los llanos de aridane
# Processing Record 12 of Set 19 | bealanana
# Processing Record 13 of Set 19 | samana
# Processing Record 14 of Set 19 | pevek
# Processing Record 15 of Set 19 | pisco
# Processing Record 16 of Set 19 | faanui
# Processing Record 17 of Set 19 | rantauprapat
# Processing Record 18 of Set 19 | zaraza
# Processing Record 19 of Set 19 | tuatapere
# Processing Record 20 of Set 19 | sorland
# Processing Record 21 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 19 | iberia
# Processing Record 23 of Set 19 | umm lajj
# Processing Record 24 of Set 19 | evensk
# Processing Record 25 of Set 19 | tunxi
# City not found. Skipping...
# Processing Record 26 of Set 19 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 19 | moose factory
# Processing Record 28 of Set 19 | qaqortoq
# Processing Record 29 of Set 19 | mehamn
# Processing Record 30 of Set 19 | laguna
# Processing Record 31 of Set 19 | victoria
# Processing Record 32 of Set 19 | urambo
# Processing Record 33 of Set 19 | cururupu
# Processing Record 34 of Set 19 | bugulma
# Processing Record 35 of Set 19 | ramonville-saint-agne
# Processing Record 36 of Set 19 | san antonio
# Processing Record 37 of Set 19 | haapu
# City not found. Skipping...
# Processing Record 38 of Set 19 | tilichiki
# Processing Record 39 of Set 19 | nikolskoye
# Processing Record 40 of Set 19 | saint george
# Processing Record 41 of Set 19 | san andres
# Processing Record 42 of Set 19 | saint-joseph
# Processing Record 43 of Set 19 | leo
# Processing Record 44 of Set 19 | guelengdeng
# City not found. Skipping...
# Processing Record 45 of Set 19 | vallenar
# Processing Record 46 of Set 19 | salaga
# Processing Record 47 of Set 19 | byron bay
# Processing Record 48 of Set 19 | hamilton
# Processing Record 49 of Set 19 | rocha
# Processing Record 50 of Set 19 | vangaindrano
# Processing Record 1 of Set 20 | tasiilaq
# Processing Record 2 of Set 20 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 20 | racale
# Processing Record 4 of Set 20 | utiel
# Processing Record 5 of Set 20 | touros
# Processing Record 6 of Set 20 | mandalgovi
# Processing Record 7 of Set 20 | mbini
# Processing Record 8 of Set 20 | mattru
# Processing Record 9 of Set 20 | herbertpur
# Processing Record 10 of Set 20 | fortuna
# Processing Record 11 of Set 20 | marzuq
# Processing Record 12 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 20 | coihaique
# Processing Record 14 of Set 20 | bomet
# Processing Record 15 of Set 20 | ingham
# Processing Record 16 of Set 20 | hasaki
# Processing Record 17 of Set 20 | vinh long
# Processing Record 18 of Set 20 | hilo
# Processing Record 19 of Set 20 | rio gallegos
# Processing Record 20 of Set 20 | airai
# Processing Record 21 of Set 20 | khatanga
# Processing Record 22 of Set 20 | dhidhdhoo
# Processing Record 23 of Set 20 | artesia
# Processing Record 24 of Set 20 | tiksi
# Processing Record 25 of Set 20 | moerai
# Processing Record 26 of Set 20 | zhangye
# Processing Record 27 of Set 20 | halifax
# Processing Record 28 of Set 20 | mahebourg
# Processing Record 29 of Set 20 | harper
# Processing Record 30 of Set 20 | half moon bay
# Processing Record 31 of Set 20 | fairbanks
# Processing Record 32 of Set 20 | asosa
# Processing Record 33 of Set 20 | makakilo city
# Processing Record 34 of Set 20 | ondangwa
# Processing Record 35 of Set 20 | ladnun
# Processing Record 36 of Set 20 | alice springs
# Processing Record 37 of Set 20 | suluq
# Processing Record 38 of Set 20 | nandgaon
# Processing Record 39 of Set 20 | east london
# Processing Record 40 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 20 | jalalabad
# Processing Record 42 of Set 20 | geraldton
# Processing Record 43 of Set 20 | les cayes
# Processing Record 44 of Set 20 | loandjili
# Processing Record 45 of Set 20 | galeana
# Processing Record 46 of Set 20 | araguatins
# City not found. Skipping...
# Processing Record 47 of Set 20 | lorengau
# Processing Record 48 of Set 20 | birao
# Processing Record 49 of Set 20 | taltal
# Processing Record 50 of Set 20 | dhanwar
# Processing Record 1 of Set 21 | ormara
# Processing Record 2 of Set 21 | hay river
# Processing Record 3 of Set 21 | aksu
# Processing Record 4 of Set 21 | dwarka
# Processing Record 5 of Set 21 | cao bang
# Processing Record 6 of Set 21 | victor harbor
# Processing Record 7 of Set 21 | broken hill
# Processing Record 8 of Set 21 | saskylakh
# Processing Record 9 of Set 21 | makokou
# Processing Record 10 of Set 21 | grindavik
# Processing Record 11 of Set 21 | borba
# Processing Record 12 of Set 21 | shimoda
# Processing Record 13 of Set 21 | havoysund
# Processing Record 14 of Set 21 | kulhudhuffushi
# Processing Record 15 of Set 21 | hualmay
# Processing Record 16 of Set 21 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 21 | portland
# Processing Record 18 of Set 21 | bandarbeyla
# Processing Record 19 of Set 21 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 21 | castro
# Processing Record 21 of Set 21 | cidreira
# Processing Record 22 of Set 21 | aripuana
# Processing Record 23 of Set 21 | khani
# Processing Record 24 of Set 21 | arraial do cabo
# Processing Record 25 of Set 21 | kadoma
# Processing Record 26 of Set 21 | witu
# Processing Record 27 of Set 21 | belyy yar
# Processing Record 28 of Set 21 | contamana
# Processing Record 29 of Set 21 | clyde river
# Processing Record 30 of Set 21 | ndioum
# Processing Record 31 of Set 21 | utrecht
# Processing Record 32 of Set 21 | kysyl-syr
# Processing Record 33 of Set 21 | angoche
# Processing Record 34 of Set 21 | bucerias
# Processing Record 35 of Set 21 | thunder bay
# Processing Record 36 of Set 21 | tomatlan
# Processing Record 37 of Set 21 | husavik
# Processing Record 38 of Set 21 | torbay
# Processing Record 39 of Set 21 | mantua
# Processing Record 40 of Set 21 | bay roberts
# Processing Record 41 of Set 21 | twentynine palms
# Processing Record 42 of Set 21 | igrim
# Processing Record 43 of Set 21 | san buenaventura
# Processing Record 44 of Set 21 | egvekinot
# Processing Record 45 of Set 21 | methoni
# Processing Record 46 of Set 21 | isangel
# Processing Record 47 of Set 21 | leningradskiy
# Processing Record 48 of Set 21 | canelones
# Processing Record 49 of Set 21 | alyangula
# Processing Record 50 of Set 21 | queimados
# Processing Record 1 of Set 22 | diplo
# Processing Record 2 of Set 22 | la ligua
# Processing Record 3 of Set 22 | rundu
# Processing Record 4 of Set 22 | rottingdean
# Processing Record 5 of Set 22 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 22 | san policarpo
# Processing Record 7 of Set 22 | takoradi
# Processing Record 8 of Set 22 | ahipara
# Processing Record 9 of Set 22 | ostrovskoye
# Processing Record 10 of Set 22 | dunedin
# Processing Record 11 of Set 22 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 22 | batsfjord
# Processing Record 13 of Set 22 | summerside
# Processing Record 14 of Set 22 | namibe
# Processing Record 15 of Set 22 | pitimbu
# Processing Record 16 of Set 22 | batouri
# Processing Record 17 of Set 22 | rumonge
# Processing Record 18 of Set 22 | luwuk
# Processing Record 19 of Set 22 | saint anthony
# Processing Record 20 of Set 22 | cabo san lucas
# Processing Record 21 of Set 22 | kavaratti
# Processing Record 22 of Set 22 | cayenne
# Processing Record 23 of Set 22 | koroni
# Processing Record 24 of Set 22 | laela
# Processing Record 25 of Set 22 | zhigansk
# Processing Record 26 of Set 22 | marechal deodoro
# Processing Record 27 of Set 22 | quatre cocos
# Processing Record 28 of Set 22 | korla
# Processing Record 29 of Set 22 | griffith
# Processing Record 30 of Set 22 | salalah
# Processing Record 31 of Set 22 | oruro
# Processing Record 32 of Set 22 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 22 | asfi
# Processing Record 34 of Set 22 | emerald
# Processing Record 35 of Set 22 | manavgat
# Processing Record 36 of Set 22 | brigantine
# Processing Record 37 of Set 22 | doha
# Processing Record 38 of Set 22 | novoraychikhinsk
# Processing Record 39 of Set 22 | ossora
# Processing Record 40 of Set 22 | axim
# Processing Record 41 of Set 22 | chebenki
# Processing Record 42 of Set 22 | flinders
# Processing Record 43 of Set 22 | huarmey
# Processing Record 44 of Set 22 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 22 | mabai
# Processing Record 46 of Set 22 | urdoma
# Processing Record 47 of Set 22 | barcelos
# Processing Record 48 of Set 22 | fort-shevchenko
# Processing Record 49 of Set 22 | padang
# Processing Record 50 of Set 22 | finale ligure
# Processing Record 1 of Set 23 | luderitz
# Processing Record 2 of Set 23 | tabukiniberu
# City not found. Skipping...
# Processing Record 3 of Set 23 | paamiut
# Processing Record 4 of Set 23 | beloha
# Processing Record 5 of Set 23 | port lavaca
# Processing Record 6 of Set 23 | bin qirdan
# Processing Record 7 of Set 23 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 23 | blagoyevo
# Processing Record 9 of Set 23 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 23 | oistins
# Processing Record 11 of Set 23 | jiangdu
# Processing Record 12 of Set 23 | saint-georges
# Processing Record 13 of Set 23 | severo-kurilsk
# Processing Record 14 of Set 23 | sindand
# City not found. Skipping...
# Processing Record 15 of Set 23 | araouane
# Processing Record 16 of Set 23 | tooele
# Processing Record 17 of Set 23 | kindu
# Processing Record 18 of Set 23 | anito
# Processing Record 19 of Set 23 | isiro
# Processing Record 20 of Set 23 | ciro marina
# Processing Record 21 of Set 23 | north bend
# Processing Record 22 of Set 23 | zlobin
# Processing Record 23 of Set 23 | teguise
# Processing Record 24 of Set 23 | norman wells
# Processing Record 25 of Set 23 | port hueneme
# Processing Record 26 of Set 23 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 23 | pacific grove
# Processing Record 28 of Set 23 | maneadero
# Processing Record 29 of Set 23 | port hedland
# Processing Record 30 of Set 23 | manzhouli
# Processing Record 31 of Set 23 | kodiak
# Processing Record 32 of Set 23 | zheleznodorozhnyy
# Processing Record 33 of Set 23 | gasa
# Processing Record 34 of Set 23 | san patricio
# Processing Record 35 of Set 23 | andenes
# Processing Record 36 of Set 23 | nioro
# Processing Record 37 of Set 23 | kroya
# Processing Record 38 of Set 23 | walvis bay
# Processing Record 39 of Set 23 | nemuro
# Processing Record 40 of Set 23 | biskamzha
# Processing Record 41 of Set 23 | lubigan
# Processing Record 42 of Set 23 | jaque
# Processing Record 43 of Set 23 | northallerton
# Processing Record 44 of Set 23 | ballina
# Processing Record 45 of Set 23 | susangerd
# Processing Record 46 of Set 23 | quchan
# Processing Record 47 of Set 23 | gayny
# Processing Record 48 of Set 23 | tiznit
# Processing Record 49 of Set 23 | richards bay
# Processing Record 50 of Set 23 | oboyan
# Processing Record 1 of Set 24 | vieste
# Processing Record 2 of Set 24 | kamaishi
# Processing Record 3 of Set 24 | dicabisagan
# Processing Record 4 of Set 24 | asau
# Processing Record 5 of Set 24 | cascais
# Processing Record 6 of Set 24 | umm kaddadah
# Processing Record 7 of Set 24 | mozarlandia
# Processing Record 8 of Set 24 | pangkalanbuun
# Processing Record 9 of Set 24 | kutum
# Processing Record 10 of Set 24 | coos bay
# Processing Record 11 of Set 24 | korem
# Processing Record 12 of Set 24 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 24 | matamoros
# Processing Record 14 of Set 24 | fare
# Processing Record 15 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 24 | sur
# Processing Record 17 of Set 24 | cairo
# Processing Record 18 of Set 24 | frankfurt
# Processing Record 19 of Set 24 | nouadhibou
# Processing Record 20 of Set 24 | san carlos de bariloche
# Processing Record 21 of Set 24 | kiama
# Processing Record 22 of Set 24 | pimentel
# Processing Record 23 of Set 24 | sechura
# Processing Record 24 of Set 24 | hambantota
# Processing Record 25 of Set 24 | pong
# Processing Record 26 of Set 24 | plettenberg bay
# Processing Record 27 of Set 24 | west bay
# Processing Record 28 of Set 24 | yambio
# Processing Record 29 of Set 24 | bassar
# Processing Record 30 of Set 24 | ambulu
# Processing Record 31 of Set 24 | glens falls
# Processing Record 32 of Set 24 | yilan
# Processing Record 33 of Set 24 | changji
# Processing Record 34 of Set 24 | kartaly
# Processing Record 35 of Set 24 | muros
# Processing Record 36 of Set 24 | omsukchan
# Processing Record 37 of Set 24 | amot
# Processing Record 38 of Set 24 | bilma
# Processing Record 39 of Set 24 | athabasca
# Processing Record 40 of Set 24 | kununurra
# Processing Record 41 of Set 24 | areosa
# Processing Record 42 of Set 24 | willowmore
# Processing Record 43 of Set 24 | the valley
# Processing Record 44 of Set 24 | beachwood
# Processing Record 45 of Set 24 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 24 | esmeraldas
# Processing Record 47 of Set 24 | kachikau
# City not found. Skipping...
# Processing Record 48 of Set 24 | mogochin
# City not found. Skipping...
# Processing Record 49 of Set 24 | gap
# Processing Record 50 of Set 24 | banff
# Processing Record 1 of Set 25 | kampong thum
# Processing Record 2 of Set 25 | ancud
# Processing Record 3 of Set 25 | el alto
# Processing Record 4 of Set 25 | amapa
# Processing Record 5 of Set 25 | greystones
# Processing Record 6 of Set 25 | pop
# Processing Record 7 of Set 25 | basco
# Processing Record 8 of Set 25 | san joaquin
# Processing Record 9 of Set 25 | isabela
# Processing Record 10 of Set 25 | zabaykalsk
# Processing Record 11 of Set 25 | anaconda
# Processing Record 12 of Set 25 | huadian
# Processing Record 13 of Set 25 | cockburn town
# Processing Record 14 of Set 25 | yumen
# Processing Record 15 of Set 25 | langxiang
# Processing Record 16 of Set 25 | santa cruz cabralia
# Processing Record 17 of Set 25 | ambon
# Processing Record 18 of Set 25 | krasnoselkup
# Processing Record 19 of Set 25 | college
# Processing Record 20 of Set 25 | dambulla
# Processing Record 21 of Set 25 | riyadh
# Processing Record 22 of Set 25 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 25 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 25 | hoi an
# Processing Record 25 of Set 25 | honolulu
# Processing Record 26 of Set 25 | chicama
# Processing Record 27 of Set 25 | esperance
# Processing Record 28 of Set 25 | tairua
# Processing Record 29 of Set 25 | sistranda
# Processing Record 30 of Set 25 | kuzino
# Processing Record 31 of Set 25 | guane
# Processing Record 32 of Set 25 | verkhnevilyuysk
# Processing Record 33 of Set 25 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 25 | ojinaga
# Processing Record 35 of Set 25 | ahumada
# City not found. Skipping...
# Processing Record 36 of Set 25 | almargem do bispo
# Processing Record 37 of Set 25 | mega
# Processing Record 38 of Set 25 | henties bay
# Processing Record 39 of Set 25 | berlevag
# Processing Record 40 of Set 25 | letnyaya stavka
# Processing Record 41 of Set 25 | smidovich
# Processing Record 42 of Set 25 | sumbe
# Processing Record 43 of Set 25 | baley
# Processing Record 44 of Set 25 | sharjah
# Processing Record 45 of Set 25 | kailua
# Processing Record 46 of Set 25 | vao
# Processing Record 47 of Set 25 | le moule
# Processing Record 48 of Set 25 | talnakh
# Processing Record 49 of Set 25 | zyryanka
# Processing Record 50 of Set 25 | zhicheng
# Processing Record 1 of Set 26 | kashi
# Processing Record 2 of Set 26 | tura
# Processing Record 3 of Set 26 | tazovskiy
# Processing Record 4 of Set 26 | caravelas
# Processing Record 5 of Set 26 | hachinohe
# Processing Record 6 of Set 26 | yarada
# Processing Record 7 of Set 26 | las cruces
# Processing Record 8 of Set 26 | kongolo
# Processing Record 9 of Set 26 | voh
# Processing Record 10 of Set 26 | birin
# Processing Record 11 of Set 26 | varadero
# Processing Record 12 of Set 26 | karratha
# Processing Record 13 of Set 26 | zhuhai
# Processing Record 14 of Set 26 | suez
# Processing Record 15 of Set 26 | inta
# Processing Record 16 of Set 26 | novikovo
# Processing Record 17 of Set 26 | azrow
# City not found. Skipping...
# Processing Record 18 of Set 26 | ouesso
# Processing Record 19 of Set 26 | swinoujscie
# Processing Record 20 of Set 26 | manzil salim
# Processing Record 21 of Set 26 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 26 | manoel urbano
# Processing Record 23 of Set 26 | tabou
# Processing Record 24 of Set 26 | kieta
# Processing Record 25 of Set 26 | ternate
# Processing Record 26 of Set 26 | alta floresta
# Processing Record 27 of Set 26 | narsaq
# Processing Record 28 of Set 26 | lamar
# Processing Record 29 of Set 26 | the pas
# Processing Record 30 of Set 26 | floro
# Processing Record 31 of Set 26 | phan thiet
# Processing Record 32 of Set 26 | comodoro rivadavia
# Processing Record 33 of Set 26 | vostok
# Processing Record 34 of Set 26 | bam
# Processing Record 35 of Set 26 | los altos
# Processing Record 36 of Set 26 | matagami
# Processing Record 37 of Set 26 | san luis
# Processing Record 38 of Set 26 | lafia
# Processing Record 39 of Set 26 | thinadhoo
# Processing Record 40 of Set 26 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 26 | coruripe
# Processing Record 42 of Set 26 | claymont
# Processing Record 43 of Set 26 | ust-tsilma
# Processing Record 44 of Set 26 | aksarka
# Processing Record 45 of Set 26 | tocopilla
# Processing Record 46 of Set 26 | denpasar
# Processing Record 47 of Set 26 | dudinka
# Processing Record 48 of Set 26 | caxito
# Processing Record 49 of Set 26 | tessaoua
# Processing Record 50 of Set 26 | sao jose da coroa grande
# Processing Record 1 of Set 27 | jiwani
# Processing Record 2 of Set 27 | coracao de jesus
# Processing Record 3 of Set 27 | senneterre
# Processing Record 4 of Set 27 | kalmunai
# Processing Record 5 of Set 27 | palaiokhora
# City not found. Skipping...
# Processing Record 6 of Set 27 | gobabis
# Processing Record 7 of Set 27 | araguaina
# Processing Record 8 of Set 27 | atherton
# Processing Record 9 of Set 27 | ostrovnoy
# Processing Record 10 of Set 27 | silver city
# Processing Record 11 of Set 27 | khandyga
# Processing Record 12 of Set 27 | ascope
# Processing Record 13 of Set 27 | grand forks
# Processing Record 14 of Set 27 | margate
# Processing Record 15 of Set 27 | todos santos
# Processing Record 16 of Set 27 | udomlya
# Processing Record 17 of Set 27 | yulin
# Processing Record 18 of Set 27 | craig
# Processing Record 19 of Set 27 | shakawe
# Processing Record 20 of Set 27 | vanimo
# Processing Record 21 of Set 27 | la asuncion
# Processing Record 22 of Set 27 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 27 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 27 | cabedelo
# Processing Record 25 of Set 27 | nara
# Processing Record 26 of Set 27 | yablochnyy
# Processing Record 27 of Set 27 | karakol
# Processing Record 28 of Set 27 | laukaa
# Processing Record 29 of Set 27 | skoghall
# Processing Record 30 of Set 27 | eselnita
# Processing Record 31 of Set 27 | bambous virieux
# Processing Record 32 of Set 27 | naples
# Processing Record 33 of Set 27 | chara
# Processing Record 34 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 27 | komsomolskiy
# Processing Record 36 of Set 27 | bilibino
# Processing Record 37 of Set 27 | marienburg
# Processing Record 38 of Set 27 | hofn
# Processing Record 39 of Set 27 | miles city
# Processing Record 40 of Set 27 | vostochnyy
# Processing Record 41 of Set 27 | carballo
# Processing Record 42 of Set 27 | numaligarh
# Processing Record 43 of Set 27 | saraland
# Processing Record 44 of Set 27 | kamenka
# Processing Record 45 of Set 27 | camacha
# Processing Record 46 of Set 27 | sicamous
# Processing Record 47 of Set 27 | xiongshi
# City not found. Skipping...
# Processing Record 48 of Set 27 | lithakia
# Processing Record 49 of Set 27 | horki
# Processing Record 50 of Set 27 | najran
# Processing Record 1 of Set 28 | road town
# Processing Record 2 of Set 28 | misratah
# Processing Record 3 of Set 28 | port macquarie
# Processing Record 4 of Set 28 | kattivakkam
# Processing Record 5 of Set 28 | sidney
# Processing Record 6 of Set 28 | yaroslavskaya
# Processing Record 7 of Set 28 | vitim
# Processing Record 8 of Set 28 | bristol
# Processing Record 9 of Set 28 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 28 | lazo
# Processing Record 11 of Set 28 | magdagachi
# Processing Record 12 of Set 28 | yanam
# Processing Record 13 of Set 28 | makasar
# Processing Record 14 of Set 28 | carovigno
# Processing Record 15 of Set 28 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 28 | tashigang
# Processing Record 17 of Set 28 | itaituba
# Processing Record 18 of Set 28 | malakal
# Processing Record 19 of Set 28 | synya
# Processing Record 20 of Set 28 | gamba
# Processing Record 21 of Set 28 | babushkin
# Processing Record 22 of Set 28 | isla mujeres
# Processing Record 23 of Set 28 | yulara
# Processing Record 24 of Set 28 | pinheiro machado
# Processing Record 25 of Set 28 | lasa
# Processing Record 26 of Set 28 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 28 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 28 | nyurba
# Processing Record 29 of Set 28 | visnes
# Processing Record 30 of Set 28 | nakano
# Processing Record 31 of Set 28 | pavda
# City not found. Skipping...
# Processing Record 32 of Set 28 | baghdad
# Processing Record 33 of Set 28 | great bend
# Processing Record 34 of Set 28 | chilca
# Processing Record 35 of Set 28 | ketchikan
# Processing Record 36 of Set 28 | sao felix do xingu
# Processing Record 37 of Set 28 | kenai
# Processing Record 38 of Set 28 | mataram
# Processing Record 39 of Set 28 | hameenlinna
# Processing Record 40 of Set 28 | karachi
# Processing Record 41 of Set 28 | high level
# Processing Record 42 of Set 28 | ambunti
# Processing Record 43 of Set 28 | saint-denis
# Processing Record 44 of Set 28 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 28 | columbus
# Processing Record 46 of Set 28 | lagoa
# Processing Record 47 of Set 28 | sisophon
# Processing Record 48 of Set 28 | sar-e pul
# Processing Record 49 of Set 28 | north myrtle beach
# Processing Record 50 of Set 28 | abha
# Processing Record 1 of Set 29 | houma
# Processing Record 2 of Set 29 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 29 | mitsamiouli
# Processing Record 4 of Set 29 | port-cartier
# Processing Record 5 of Set 29 | prieska
# Processing Record 6 of Set 29 | katiola
# Processing Record 7 of Set 29 | turtas
# Processing Record 8 of Set 29 | otuzco
# Processing Record 9 of Set 29 | uirauna
# Processing Record 10 of Set 29 | cairns
# Processing Record 11 of Set 29 | puerto madero
# Processing Record 12 of Set 29 | maceio
# Processing Record 13 of Set 29 | pombas
# Processing Record 14 of Set 29 | magistralnyy
# Processing Record 15 of Set 29 | svendborg
# Processing Record 16 of Set 29 | aklavik
# Processing Record 17 of Set 29 | namatanai
# Processing Record 18 of Set 29 | omboue
# Processing Record 19 of Set 29 | ust-uda
# Processing Record 20 of Set 29 | waingapu
# Processing Record 21 of Set 29 | bugko
# Processing Record 22 of Set 29 | raudeberg
# Processing Record 23 of Set 29 | ambilobe
# Processing Record 24 of Set 29 | vung tau
# Processing Record 25 of Set 29 | dariba
# Processing Record 26 of Set 29 | kruisfontein
# Processing Record 27 of Set 29 | kirakira
# Processing Record 28 of Set 29 | garmsar
# Processing Record 29 of Set 29 | talcahuano
# Processing Record 30 of Set 29 | maraba
# Processing Record 31 of Set 29 | iracoubo
# Processing Record 32 of Set 29 | bongandanga
# Processing Record 33 of Set 29 | fayaoue
# Processing Record 34 of Set 29 | matadi
# Processing Record 35 of Set 29 | broome
# Processing Record 36 of Set 29 | turka
# Processing Record 37 of Set 29 | peterhead
# Processing Record 38 of Set 29 | nizhneangarsk
# Processing Record 39 of Set 29 | knysna
# Processing Record 40 of Set 29 | iaciara
# Processing Record 41 of Set 29 | fort nelson
# Processing Record 42 of Set 29 | camapua
# Processing Record 43 of Set 29 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 29 | champerico
# Processing Record 45 of Set 29 | barroualie
# City not found. Skipping...
# Processing Record 46 of Set 29 | katsiveli
# City not found. Skipping...
# Processing Record 47 of Set 29 | shimanovsk
# Processing Record 48 of Set 29 | maldonado
# Processing Record 49 of Set 29 | dali
# Processing Record 50 of Set 29 | manggar
# Processing Record 1 of Set 30 | port keats
# Processing Record 2 of Set 30 | erzin
# Processing Record 3 of Set 30 | kharp
# Processing Record 4 of Set 30 | kismayo
# Processing Record 5 of Set 30 | panguna
# Processing Record 6 of Set 30 | rapid valley
# Processing Record 7 of Set 30 | nogliki
# Processing Record 8 of Set 30 | chapais
# Processing Record 9 of Set 30 | olinda
# Processing Record 10 of Set 30 | kayes
# Processing Record 11 of Set 30 | pasinler
# Processing Record 12 of Set 30 | jiaocheng
# Processing Record 13 of Set 30 | tokur
# Processing Record 14 of Set 30 | bratsk
# Processing Record 15 of Set 30 | soverato
# Processing Record 16 of Set 30 | ixtapa
# Processing Record 17 of Set 30 | puteyets
# Processing Record 18 of Set 30 | buariki
# City not found. Skipping...
# Processing Record 19 of Set 30 | centralia
# Processing Record 20 of Set 30 | kochevo
# Processing Record 21 of Set 30 | svetlyy
# Processing Record 22 of Set 30 | visegrad
# Processing Record 23 of Set 30 | stykkisholmur
# Processing Record 24 of Set 30 | bolobo
# Processing Record 25 of Set 30 | ushtobe
# Processing Record 26 of Set 30 | saint-leu
# Processing Record 27 of Set 30 | adjumani
# Processing Record 28 of Set 30 | mangrol
# Processing Record 29 of Set 30 | kolpashevo
# Processing Record 30 of Set 30 | caraballeda
# Processing Record 31 of Set 30 | sonoita
# Processing Record 32 of Set 30 | khor
# Processing Record 33 of Set 30 | kingaroy
# Processing Record 34 of Set 30 | payo
# Processing Record 35 of Set 30 | zhezkazgan
# Processing Record 36 of Set 30 | varena
# Processing Record 37 of Set 30 | astipalaia
# City not found. Skipping...
# Processing Record 38 of Set 30 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 30 | san quintin
# Processing Record 40 of Set 30 | kon tum
# Processing Record 41 of Set 30 | jitra
# Processing Record 42 of Set 30 | shenjiamen
# Processing Record 43 of Set 30 | salinas
# Processing Record 44 of Set 30 | kota bahru
# Processing Record 45 of Set 30 | iquique
# Processing Record 46 of Set 30 | lavumisa
# Processing Record 47 of Set 30 | nenjiang
# Processing Record 48 of Set 30 | tautira
# Processing Record 49 of Set 30 | te anau
# Processing Record 50 of Set 30 | kualakapuas
# Processing Record 1 of Set 31 | oranjestad
# Processing Record 2 of Set 31 | barra da estiva
# Processing Record 3 of Set 31 | ust-kuyga
# Processing Record 4 of Set 31 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 31 | miracatu
# Processing Record 6 of Set 31 | kurumkan
# Processing Record 7 of Set 31 | yanaul
# Processing Record 8 of Set 31 | wewak
# Processing Record 9 of Set 31 | mizdah
# Processing Record 10 of Set 31 | kaifeng
# Processing Record 11 of Set 31 | valenca do piaui
# Processing Record 12 of Set 31 | lata
# Processing Record 13 of Set 31 | spas-demensk
# Processing Record 14 of Set 31 | ibra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaires to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kuminskiy      RU  58.6667   66.5667     33.06        76          94
# 1          Kapaa      US  22.0752 -159.3190     82.72        72          90
# 2       Zaliztsi      UA  49.7919   25.3730     44.74        58           7
# 3         Atuona      PF  -9.8000 -139.0333     78.28        74          19
# 4   Puerto Ayora      EC  -0.7393  -90.3518     75.16        89          89
# 5          Vaini      TO -21.2000 -175.2000     77.16        83          75
# 6        Rikitea      PF -23.1203 -134.9692     73.11        68          24
# 7       Hermanus      ZA -34.4187   19.2345     51.91        65          75
# 8     Bogovarovo      RU  58.9785   47.0246     43.23        95         100
# 9  Mar Del Plata      AR -38.0023  -57.5575     55.13        62          90
#
#    Wind Speed Current Description
# 0        7.58     overcast clouds
# 1        5.01          light rain
# 2       10.27           clear sky
# 3       20.42          few clouds
# 4        9.24     overcast clouds
# 5       12.66       broken clouds
# 6       21.39          few clouds
# 7        1.68       broken clouds
# 8        2.91     overcast clouds
# 9        4.00     overcast clouds

# %%
# Create the output file (csv)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
